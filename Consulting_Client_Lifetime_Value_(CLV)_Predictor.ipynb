# %% [markdown]
# <a href="https://colab.research.google.com/github/justicec387-prog/Portfolio/blob/main/Consulting_Client_Lifetime_Value_(CLV)_Predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# 1. Create Mock Consulting Data
np.random.seed(42)
clients = [f'Client_{i}' for i in range(1, 51)]
industries = ['Legal', 'Tech', 'Healthcare', 'Real Estate']

data = {
    'client_id': clients,
    'industry': np.random.choice(industries, 50),
    'monthly_billable': np.random.randint(5000, 25000, 50),
    'engagement_hours': np.random.randint(10, 100, 50),
    'last_interaction_days': np.random.randint(1, 45, 50),
    'contract_length_months': np.random.choice([6, 12, 24], 50)
}

consulting_df = pd.DataFrame(data)
consulting_df.to_csv('consulting_ops_data.csv', index=False)
print("Director's Audit: Consulting Operations Data Generated.")
print(consulting_df.head())
# Out:
# Director's Audit: Consulting Operations Data Generated.
#   client_id     industry  monthly_billable  engagement_hours  \
# 0  Client_1   Healthcare             24118                24
# 1  Client_2  Real Estate              8005                54
# 2  Client_3        Legal              6899                74
# 3  Client_4   Healthcare              6267                98
# 4  Client_5   Healthcare             22912                80
#
#    last_interaction_days  contract_length_months
# 0                     32                       6
# 1                     39                       6
# 2                     32                      12
# 3                      4                       6
# 4                     30                      12
